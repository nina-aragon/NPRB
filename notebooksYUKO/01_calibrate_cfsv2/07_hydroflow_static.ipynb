# %% [markdown]
# ## Create static files for hydroflow

# %%
# The cells in this notebook run each step in the HydroFlow workflow
# This workflow was developed to function from within the designated SnowModel
# folder for each domain.

# Import all of the python packages used in this workflow.
from datetime import date, datetime
import json
import os
import requests

# Choose a domain
domain = 'YUKO'

# paths 
SMpath = '/nfs/attic/dfh/2020_NPRB/domain_'+domain+'/snowmodel2023_cfsv2/'
SMdatapath = '/nfs/attic/dfh/2020_NPRB/data/SMinputs/'+domain+'/'
# mkgdatpath = SMdatapath+'mk_grads_from_ascii_topoveg.f'
# topovegfile = 'dem_veg_'+domain+'.gdat'
# directionspath = SMdatapath+'direction/'
# watershedpath = SMdatapath+'watershed/'

#path to NPRB domains
domains_resp = requests.get("https://raw.githubusercontent.com/NPRB/02_preprocess_python/main/NPRB_domains.json")
domains = domains_resp.json()
    
# domain parameters
nx = domains[domain]['ncols']
ny = domains[domain]['nrows']
clsz = domains[domain]['cellsize']
xll = domains[domain]['xll']
yll = domains[domain]['yll']
st_dt = '2011-10-01'

# %% [markdown]
# ## Define functions

# %%
# Function to edit fortran files
def replace_line(file_name, line_num, text):
    lines = open(file_name, 'r').readlines()
    lines[line_num] = text
    out = open(file_name, 'w')
    out.writelines(lines)
    out.close()

# %%
# Function to write out .ctl file for hydroflow steps
def disc_ctl(var,path,nx,ny,xll,yll,stdt,nt=1):
    '''
    vars can be:
    disc = hydroflow discharge
    tc = time coefficients
    watershed = watershed
    dir = flow direction 
    '''
    dt = datetime.strptime(st_dt, '%Y-%m-%d').strftime('%M:%SZ%d%b%Y')
    if var == 'disc':
        # Capture some variables from this SnowModel simulation
        lines = ['DSET ^disc.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 2',\
                 'slow 1 0 SLOW',\
                 'fast 1 0 FAST',\
                 'ENDVARS']
    elif var == 'tc':
        lines = ['DSET ^tc.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 2',\
                 'tcoef_slow 1 0 TCSLOW',\
                 'tcoef_fast 1 0 TCFAST',\
                 'ENDVARS']
    elif var == 'watershed':
        lines = ['DSET ^watershed.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 3',\
                 'dir 1 0 flow direction',\
                 'wshed 1 0 watersheds',\
                 'order 1 0 flow accumulation',\
                 'ENDVARS']
    elif var == 'dir':
        lines = ['DSET ^dir.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 1',\
                 'dir 1 0 flow direction',\
                 'ENDVARS']       

    with open(path, 'w') as f:
        for line in lines:
            f.write(line)
            f.write('\n')

    f.close()

# %% [markdown]
# ## Build combined dem and veg gdat & ctl files
#
# Inputs:
# * [domain]+'_veg.asc'
# * [domain]+'_dem.asc'
#
# Outputs:
#
# * dem_veg_[domain].gdat
# * dem_veg_[domain].ctl

# %%
# Path to dem and veg files
dem_fname = domain+'_demHF.asc'
veg_fname = domain+'_vegHF.asc'
demveg_fname = 'dem_veg_'+domain+'.gdat'
demveg_ctl = 'dem_veg_'+domain+'.ctl'
topoveg_path = SMpath+'topo_vege/'

# Path to the flow directions fortran file for editing
mkgdat_fortran = SMdatapath+'mk_grads_from_ascii_topoveg.f'
print(mkgdat_fortran)

# edit the .f file for the domain
replace_line(mkgdat_fortran, 7, '      parameter (nx='+nx+',ny='+ny+')\n')
replace_line(mkgdat_fortran, 12, '      open (21,file=\''+dem_fname+'\')\n')
replace_line(mkgdat_fortran, 13, '      open (22,file=\''+veg_fname+'\')\n')
replace_line(mkgdat_fortran, 26, '      open (31,file=\''+demveg_fname+'\',\n')
# Out:
# /nfs/attic/dfh/2020_NPRB/data/SMinputs/YUKO/mk_grads_from_ascii_topoveg.f

# %%
# execute the function
# Use line magic to change directories to the file locations
# Run the fortran script and save the output
# %cd $SMdatapath
# !gfortran mk_grads_from_ascii_topoveg.f
# !./a.out
# Out:
# /nfs/attic/dfh/2020_NPRB/data/SMinputs/YUKO

# %%
# write out corresponding .ctl file
ctl_list = ['DSET ^'+demveg_fname,
            'TITLE xxxxxxxxxxxxxxxxxxxxxxxxx',
            'UNDEF  -9999.0',
            'XDEF   '+nx+' LINEAR '+xll+' '+clsz,
            'YDEF   '+ny+' LINEAR '+yll+' '+clsz,
            'ZDEF    1 LEVELS 1',
            'TDEF    1 LINEAR 00Z01sep2001 1dy',
            'VARS    2',
            'topo    0  0 topo(m)',
            'veg     0  0 veg type',
            'ENDVARS']
with open(demveg_ctl, 'w') as f:
    f.write('\n'.join(ctl_list))

# %%
# move files to modeling space 
# !mv $demveg_fname $topoveg_path
# !mv $demveg_ctl $topoveg_path

# %% [markdown]
# ### Create flow directions output file
#
# Inputs:
# * dem_veg_[domain].gdat
#
# Outputs:
#
# * dir_[domain].gdat

# %%
# Paths to input/output file
demveg_fname = 'dem_veg_'+domain+'.gdat'
dir_fname = 'dir.gdat'
dir_ctl = 'dir.ctl' 

# Path to directions folder
dirs_path = SMpath+'direction/'

# Path to the flow directions fortran file for editing
dirs_fortran = SMpath+'direction/get_flow_dirs.f'
print(dirs_fortran)

# Run the replace line function in order to change the name of the input 
# and output files in the script
replace_line(dirs_fortran, 6, '      nx = '+nx+'\n')
replace_line(dirs_fortran, 7, '      ny = '+ny+'\n')
replace_line(dirs_fortran, 15, '      demfile = \'../topo_vege/'+demveg_fname+'\'\n')
replace_line(dirs_fortran, 19, '      dirfile = \''+dir_fname+'\'\n')

# Use line magic to change directories to the file locations
# Run the fortran script and save the output
# %cd $dirs_path
# !gfortran get_flow_dirs.f
# !./a.out

#print .ctl file
ctlpath = dirs_path+'dir.ctl'
disc_ctl('dir',ctlpath,nx,ny,xll,yll,st_dt)
# Out:
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/direction/get_flow_dirs.f
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/direction
# get_flow_dirs.f:1084.72:
#
#       IF(J.GT.97.OR.J.LT.1) PAUSE
#                                                                         1
# Warning: Deleted feature: PAUSE statement at (1)
#
# N Rows =  527 N Columns =  863 N Nodes =  454801
#
# COMPUTING PRIMARY FLOW DIRECTIONS
#
#    Downward pass  1 FIRSTL =     1 LASTL =   527
#    Downward pass  2 FIRSTL =     1 LASTL =   527
#    Downward pass  3 FIRSTL =     1 LASTL =   527
#    Downward pass  4 FIRSTL =     1 LASTL =   527
#    Downward pass  5 FIRSTL =     1 LASTL =   527
#    Downward pass  6 FIRSTL =     1 LASTL =   527
#    Downward pass  7 FIRSTL =     1 LASTL =   527
#    Downward pass  8 FIRSTL =     1 LASTL =   527
#    Downward pass  9 FIRSTL =     1 LASTL =   527
#    Downward pass 10 FIRSTL =     1 LASTL =   527
#    Downward pass 11 FIRSTL =     1 LASTL =   527
#    Downward pass 12 FIRSTL =     1 LASTL =   527
#    Downward pass 13 FIRSTL =     1 LASTL =   527
#    Downward pass 14 FIRSTL =     1 LASTL =   527
#    Downward pass 15 FIRSTL =     1 LASTL =   527
#
# COULD NOT SOLVE FOR ALL CELLS
#
#
# COMPUTING COUNTS (CATCHMENT AREAS)
#
#    Resolved = 274341 Unresolved = 180460
#    Downward pass    1
#    Resolved = 376114 Unresolved =  78687
#    Upward pass    2
#    Resolved = 422256 Unresolved =  32545
#    Downward pass    3
#    Resolved = 433637 Unresolved =  21164
#    Upward pass    4
#    Resolved = 440359 Unresolved =  14442
#    Downward pass    5
#    Resolved = 443887 Unresolved =  10914
#    Upward pass    6
#    Resolved = 446386 Unresolved =   8415
#    Downward pass    7
#    Resolved = 447986 Unresolved =   6815
#    Upward pass    8
#    Resolved = 449377 Unresolved =   5424
#    Downward pass    9
#    Resolved = 450089 Unresolved =   4712
#    Upward pass   10
#    Resolved = 450757 Unresolved =   4044
#    Downward pass   11
#    Resolved = 451279 Unresolved =   3522
#    Upward pass   12
#    Resolved = 451589 Unresolved =   3212
#    Downward pass   13
#    Resolved = 451872 Unresolved =   2929
#    Upward pass   14
#    Resolved = 452132 Unresolved =   2669
#    Downward pass   15
#    Resolved = 452366 Unresolved =   2435
#    Upward pass   16
#    Resolved = 452515 Unresolved =   2286
#    Downward pass   17
#    Resolved = 452658 Unresolved =   2143
#    Upward pass   18
#    Resolved = 452865 Unresolved =   1936
#    Downward pass   19
#    Resolved = 452969 Unresolved =   1832
#    Upward pass   20
#    Resolved = 453135 Unresolved =   1666
#    Downward pass   21
#    Resolved = 453211 Unresolved =   1590
#    Upward pass   22
#    Resolved = 453326 Unresolved =   1475
#    Downward pass   23
#    Resolved = 453434 Unresolved =   1367
#    Upward pass   24
#    Resolved = 453486 Unresolved =   1315
#    Downward pass   25
#    Resolved = 453558 Unresolved =   1243
#    Upward pass   26
#    Resolved = 453601 Unresolved =   1200
#    Downward pass   27
#    Resolved = 453663 Unresolved =   1138
#    Upward pass   28
#    Resolved = 453689 Unresolved =   1112
#    Downward pass   29
#    Resolved = 453704 Unresolved =   1097
#    Upward pass   30
#    Resolved = 453710 Unresolved =   1091
#    Downward pass   31
#    Resolved = 453725 Unresolved =   1076
#    Upward pass   32
#    Resolved = 453739 Unresolved =   1062
#    Downward pass   33
#    Resolved = 453747 Unresolved =   1054
#    Upward pass   34
#    Resolved = 453755 Unresolved =   1046
#    Downward pass   35
#    Resolved = 453762 Unresolved =   1039
#    Upward pass   36
#    Resolved = 453776 Unresolved =   1025
#    Downward pass   37
#    Resolved = 453780 Unresolved =   1021
#    Upward pass   38
#    Resolved = 453782 Unresolved =   1019
#    Downward pass   39
#    Resolved = 453790 Unresolved =   1011
#    Upward pass   40
#    Resolved = 453826 Unresolved =    975
#    Downward pass   41
#    Resolved = 453830 Unresolved =    971
#    Upward pass   42
#    Resolved = 453909 Unresolved =    892
#    Downward pass   43
#    Resolved = 453913 Unresolved =    888
#    Upward pass   44
#    Resolved = 453923 Unresolved =    878
#    Downward pass   45
#    Resolved = 453926 Unresolved =    875
#    Upward pass   46
#    Resolved = 453930 Unresolved =    871
#    Downward pass   47
#    Resolved = 453933 Unresolved =    868
#    Upward pass   48
#    Resolved = 454013 Unresolved =    788
#    Downward pass   49
#    Resolved = 454016 Unresolved =    785
#    Upward pass   50
#    Resolved = 454025 Unresolved =    776
#    Downward pass   51
#    Resolved = 454033 Unresolved =    768
#    Upward pass   52
#    Resolved = 454037 Unresolved =    764
#    Downward pass   53
#    Resolved = 454067 Unresolved =    734
#    Upward pass   54
#    Resolved = 454080 Unresolved =    721
#    Downward pass   55
#    Resolved = 454086 Unresolved =    715
#    Upward pass   56
#    Resolved = 454107 Unresolved =    694
#    Downward pass   57
#    Resolved = 454110 Unresolved =    691
#    Upward pass   58
#    Resolved = 454201 Unresolved =    600
#    Downward pass   59
#    Resolved = 454256 Unresolved =    545
#    Upward pass   60
#    Resolved = 454289 Unresolved =    512
#    Downward pass   61
#    Resolved = 454309 Unresolved =    492
#    Upward pass   62
#    Resolved = 454324 Unresolved =    477
#    Downward pass   63
#    Resolved = 454344 Unresolved =    457
#    Upward pass   64
#    Resolved = 454349 Unresolved =    452
#    Downward pass   65
#    Resolved = 454377 Unresolved =    424
#    Upward pass   66
#    Resolved = 454378 Unresolved =    423
#    Downward pass   67
#    Resolved = 454387 Unresolved =    414
#    Upward pass   68
#    Resolved = 454399 Unresolved =    402
#    Downward pass   69
#    Resolved = 454404 Unresolved =    397
#    Upward pass   70
#    Resolved = 454410 Unresolved =    391
#    Downward pass   71
#    Resolved = 454443 Unresolved =    358
#    Upward pass   72
#    Resolved = 454445 Unresolved =    356
#    Downward pass   73
#    Resolved = 454478 Unresolved =    323
#    Upward pass   74
#    Resolved = 454480 Unresolved =    321
#    Downward pass   75
#    Resolved = 454485 Unresolved =    316
#    Upward pass   76
#    Resolved = 454500 Unresolved =    301
#    Downward pass   77
#    Resolved = 454502 Unresolved =    299
#    Upward pass   78
#    Resolved = 454505 Unresolved =    296
#    Downward pass   79
#    Resolved = 454634 Unresolved =    167
#    Upward pass   80
#    Resolved = 454635 Unresolved =    166
#    Downward pass   81
#    Resolved = 454662 Unresolved =    139
#    Upward pass   82
#    Resolved = 454665 Unresolved =    136
#    Downward pass   83
#    Resolved = 454671 Unresolved =    130
#    Upward pass   84
#    Resolved = 454675 Unresolved =    126
#    Downward pass   85
#    Resolved = 454700 Unresolved =    101
#    Upward pass   86
#    Resolved = 454728 Unresolved =     73
#    Downward pass   87
#    Resolved = 454735 Unresolved =     66
#    Upward pass   88
#    Resolved = 454737 Unresolved =     64
#    Downward pass   89
#    Resolved = 454740 Unresolved =     61
#    Upward pass   90
#    Resolved = 454795 Unresolved =      6
#    Downward pass   91
#    Resolved = 454801 Unresolved =      0
#    Upward pass   92
#    Resolved = 454801 Unresolved =      0

# %%
# # write out corresponding .ctl file
# ctl_list = ['DSET ^'+dir_fname,
#             'TITLE xxxxxxxxxxxxxxxxxxxxxxxxx',
#             'UNDEF  -9999.0',
#             'XDEF   '+nx+' LINEAR '+xll+' '+clsz,
#             'YDEF   '+ny+' LINEAR '+yll+' '+clsz,
#             'ZDEF    1 LEVELS 1',
#             'TDEF    1 LINEAR 00Z01sep2001 1dy',
#             'VARS    1',
#             'dir 1 0 flow direction',
#             'ENDVARS']

# with open(dir_ctl, 'w') as f:
#     f.write('\n'.join(ctl_list))

# %% [markdown]
# ### Create the Watersheds output file
#
# Inputs:
# * dem_veg_[domain].gdat
# * dir_[domain].gdat
#
# Outputs:
#
# *  watersheds.gdat
# * watersheds_index.txt

# %%
# # Paths to input/output file
# demveg_fname = 'dem_veg_'+domain+'.gdat'
# dir_fname = 'dir.gdat'
# wshed_fname = 'watershed_upslope.gdat'
# wshed_ctl = 'watershed_upslope.ctl'
# wshedidx_fname = 'watershed_index_upslope.txt'

# # Path to watersheds folder
# wshed_path = SMpath+'watershed/'

# # Path to the watersheds fortran file for editing
# wshed_fortran = SMpath+'watershed/mk_watersheds.f'
# print(wshed_fortran)

# # Run the replace line function in order to change the name of the input 
# # and output files in the script

# replace_line(wshed_fortran, 11, '      parameter (nx='+nx+',ny='+ny+')\n')
# replace_line(wshed_fortran, 34, '      open (unit=51,file=\'../direction/'+dir_fname+'\',\n')
# replace_line(wshed_fortran, 39, '      open (unit=61,file=\'../topo_vege/'+demveg_fname+'\',\n')
# replace_line(wshed_fortran, 65, '      open (unit=41,file=\''+wshedidx_fname+'\')\n')
# replace_line(wshed_fortran, 73, '      open (unit=61,file=\''+wshed_fname+'\',\n')

# # Use line magic to change directories to the file locations
# # Run the fortran script and save the output
# %cd $wshed_path
# !gfortran mk_watersheds.f
# !./a.out

# #print .ctl file
# ctlpath = wshed_path+wshed_ctl
# disc_ctl('watershed',ctlpath,nx,ny,xll,yll,st_dt)
# Out:
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/watershed/mk_watersheds.f
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/watershed
#
#  calculating grid cell connectivity
#
#  identifying watersheds
#
# ^C

# %%
# Paths to input/output file
demveg_fname = 'dem_veg_'+domain+'.gdat'
dir_fname = 'dir.gdat'
wshed_fname = 'watershed.gdat'
wshed_ctl = 'watershed.ctl'
wshedidx_fname = 'watershed_index.txt'

# Path to watersheds folder
wshed_path = SMpath+'watershed/'

# Path to the watersheds fortran file for editing
wshed_fortran = SMpath+'watershed/mk_watersheds.f'
print(wshed_fortran)

# Run the replace line function in order to change the name of the input 
# and output files in the script

replace_line(wshed_fortran, 11, '      parameter (nx='+nx+',ny='+ny+')\n')
replace_line(wshed_fortran, 34, '      open (unit=51,file=\'../direction/'+dir_fname+'\',\n')
replace_line(wshed_fortran, 39, '      open (unit=61,file=\'../topo_vege/'+demveg_fname+'\',\n')
replace_line(wshed_fortran, 65, '      open (unit=41,file=\''+wshedidx_fname+'\')\n')
replace_line(wshed_fortran, 73, '      open (unit=61,file=\''+wshed_fname+'\',\n')

# Use line magic to change directories to the file locations
# Run the fortran script and save the output
# %cd $wshed_path
# !gfortran mk_watersheds.f
# !./a.out

#print .ctl file
ctlpath = wshed_path+wshed_ctl
disc_ctl('watershed',ctlpath,nx,ny,xll,yll,st_dt)
# Out:
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/watershed/mk_watersheds.f
# /nfs/attic/dfh/2020_NPRB/domain_YUKO/snowmodel2023_cfsv2/watershed
#
#  calculating grid cell connectivity
#
#  identifying watersheds
#
#  defining watershed connectivity
#
#  calculating ODE numbers and positions
#       1) working on watershed number        1000
#       1) working on watershed number        2000
#       1) working on watershed number        3000
#       1) working on watershed number        4000
#
#  creating the connectivity index
#
#  listing the connectivity information in sequential order
#       2) working on watershed number        1000
#       2) working on watershed number        2000
#       2) working on watershed number        3000
#       2) working on watershed number        4000
#
#  defining the solution order of the watershed grid cells
#       3) working on watershed number        1000
#       3) working on watershed number        2000
#       3) working on watershed number        3000
#       3) working on watershed number        4000
#
#  performing some cleanup duties
#       4) working on watershed number        1000
#       4) working on watershed number        2000
#       4) working on watershed number        3000
#       4) working on watershed number        4000
#
#  creating the final indexing array
#       5) working on watershed number        1000
#       5) working on watershed number        2000
#       5) working on watershed number        3000
#       5) working on watershed number        4000
#
#
#  FINAL WATERSHED COUNT =         4868

# %%
# # write out corresponding .ctl file
# ctl_list = ['DSET ^'+wshed_fname,
#             'TITLE xxxxxxxxxxxxxxxxxxxxxxxxx',
#             'UNDEF  -9999.0',
#             'XDEF   '+nx+' LINEAR '+xll+' '+clsz,
#             'YDEF   '+ny+' LINEAR '+yll+' '+clsz,
#             'ZDEF    1 LEVELS 1',
#             'TDEF    1 LINEAR 00Z01sep2001 1dy',
#             'VARS    3',
#             'dir 1 0 flow direction',
#             'wshed 1 0 watersheds',
#             'order 1 0 flow accumulation',
#             'ENDVARS']

# with open(wshed_ctl, 'w') as f:
#     f.write('\n'.join(ctl_list))
