# %%
# The cells in this notebook run each step in the HydroFlow workflow
# This workflow was developed to function from within the designated SnowModel
# folder for each domain.

# Import all of the python packages used in this workflow.
import scipy
import numpy as np
from collections import OrderedDict
import os, sys
from pylab import *
import pandas as pd
import numpy as np
import xarray as xr
import geopandas as gpd
from datetime import date, datetime
from datetime import timedelta  
import json
import itertools
import requests
import os

# Choose a domain
domain = 'BEAU'

# Path to the SnowModel folder
SMpath = '/nfs/attic/dfh/2020_NPRB/domain_'+domain+'/snowmodel2023_cfsv2/'
#SMpath = '/scratch/Nina/NPRB/domain_'+domain+'/snowmodel2023_cfsv2/'

#path to NPRB domains
domains_resp = requests.get("https://raw.githubusercontent.com/NPRB/02_preprocess_python/main/NPRB_domains.json")
domains = domains_resp.json()
    
# Define nx and ny for this domain to be used later
nx = domains[domain]['ncols']
ny = domains[domain]['nrows']
clsz = domains[domain]['cellsize']
xll = domains[domain]['xll']
yll = domains[domain]['yll']

start_years = list(range(1989,2019))

# %%
# Function to edit fortran files
def replace_line(file_name, line_num, text):
    lines = open(file_name, 'r').readlines()
    lines[line_num] = text
    out = open(file_name, 'w')
    out.writelines(lines)
    out.close()

# %%
# Function to write out .ctl file for hydroflow steps
def disc_ctl(var,path,nx,ny,xll,yll,stdt,yrlabel,nt=1):
    '''
    vars can be:
    disc = hydroflow discharge
    tc = time coefficients
    watershed = watershed
    dir = flow direction 
    '''
    dt = datetime.strptime(st_dt, '%Y-%m-%d').strftime('%M:%SZ%d%b%Y')
    if var == 'disc':
        # Capture some variables from this SnowModel simulation
        lines = ['DSET ^disc_'+yrlabel+'.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 2',\
                 'slow 1 0 SLOW',\
                 'fast 1 0 FAST',\
                 'ENDVARS']
    elif var == 'tc':
        lines = ['DSET ^tc_'+yrlabel+'.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 2',\
                 'tcoef_slow 1 0 TCSLOW',\
                 'tcoef_fast 1 0 TCFAST',\
                 'ENDVARS']
    elif var == 'watershed':
        lines = ['DSET ^watershed.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 3',\
                 'dir 1 0 flow direction',\
                 'wshed 1 0 watersheds',\
                 'order 1 0 flow accumulation',\
                 'ENDVARS']
    elif var == 'dir':
        lines = ['DSET ^dir.gdat',\
                 'UNDEF -9999.0',\
                 'OPTIONS BINPRECISION float32',\
                 'XDEF '+nx+' LINEAR '+xll+' '+clsz,\
                 'YDEF '+ny+' LINEAR '+yll+' '+clsz,\
                 'ZDEF 1 LEVELS 1',\
                 'TDEF '+str(nt)+' LINEAR '+dt+' 1dy',\
                 'VARS 1',\
                 'dir 1 0 flow direction',\
                 'ENDVARS']       

    with open(path, 'w') as f:
        for line in lines:
            f.write(line)
            f.write('\n')

    f.close()

# %%
for styr in start_years:
    print(styr)
    # file naming/organization 
    yrlabel = str(styr+81)+'-'+str(styr+82)
    #start date    
    st_dt = str(styr)+'-10-01'
    #end date
    ed_dt = str(styr+2)+'-09-30'
    
    # RUN TC

    # Path to single dem/veg file
    dem_veg = SMpath+'topo_vege/dem_veg_'+domain+'_fut.gdat'

    # Path to directions folder
    tc_path = SMpath+'timecoef_fut/'

    # Path to the flow directions fortran file for editing
    tc_fortran = SMpath+'timecoef_fut/timecoefs.f'

    # Create the years variable for use later
    print('Working on timecoefs')

    # Output path
    out_path = SMpath+'outputs_fut/'

    # The number of days in the simulation
    num_days = str((datetime.strptime(ed_dt, '%Y-%m-%d')-datetime.strptime(st_dt, '%Y-%m-%d')).days+1)

    # Run the replace line function in order to change the name of the input 
    # and output files in the script
    replace_line(tc_fortran, 9, '      parameter (nx='+nx+',ny='+ny+')\n')
    replace_line(tc_fortran, 11, '      parameter (max_iter='+num_days+')\n')
    replace_line(tc_fortran, 48, '     &  \'../topo_vege/dem_veg_'+domain+'.gdat\',\n')
    replace_line(tc_fortran, 56, '     &  file=\'../outputs_fut/swed_'+yrlabel+'.gdat\',\n')
    replace_line(tc_fortran, 205, '      open (unit=71,file=\'../outputs_fut/tc_'+yrlabel+'.gdat\',\n')

    # Use line magic to change directories to the file locations
    # Run the fortran script and save the output
    # %cd $tc_path
    # !gfortran -mcmodel=medium timecoefs.f
    # !./a.out

    # write a .ctl file for tcs
    ctlpath = out_path+'tc_'+yrlabel+'.ctl'
    disc_ctl('tc',ctlpath,nx,ny,xll,yll,st_dt,yrlabel,nt=num_days)
    #     # Print out a metadata textfile
    #     meta(domain,name,out_path)
    print('tc gdat created for '+domain+' domain')
    
    
    
    # RUN HF

    # Path to single dem/veg file
    dem_veg = SMpath+'topo_vege/dem_veg_'+domain+'.gdat'

    # Path to hydroflow folder
    hf_path = SMpath+'hydroflow_fut/'

    # Path to the flow directions fortran file for editing
    hf_fortran = SMpath+'hydroflow_fut/hydroflow.f'

    # Create the years variable for use later
    print('Working on HydroFlow')

    # Output path
    out_path = SMpath+'outputs_fut/'

    # The number of days in the simulation
    num_days = str((datetime.strptime(ed_dt, '%Y-%m-%d')-datetime.strptime(st_dt, '%Y-%m-%d')).days+1)


    # Run the replace line function in order to change the name of the input 
    # and output files in the script
    replace_line(hf_fortran, 9, '      parameter (nx='+nx+',ny='+ny+',nxny=nx*ny)\n')
    replace_line(hf_fortran, 10, '      parameter (max_iter='+num_days+')\n')
    replace_line(hf_fortran, 37, '      deltax = '+clsz+'\n')
    replace_line(hf_fortran, 38, '      deltay = '+clsz+'\n')
    replace_line(hf_fortran, 49, '      open (unit=41,file=\'../watershed/watershed_index.txt\')\n')
    replace_line(hf_fortran, 64, '     &  file=\'../outputs_fut/rofx_'+yrlabel+'.gdat\',\n')
    replace_line(hf_fortran, 86, '      open (81,file=\'../outputs_fut/tc_'+yrlabel+'.gdat\',\n')
    replace_line(hf_fortran, 280, '      open (unit=71,file=\'../outputs_fut/disc_'+yrlabel+'.gdat\',\n')

    # Use line magic to change directories to the file locations
    # Run the fortran script and save the output
    # %cd $hf_path
    # !gfortran -mcmodel=medium hydroflow.f
    # !./a.out

    # write a .ctl file for discharge
    ctlpath = out_path+'disc_'+yrlabel+'.ctl'
    disc_ctl('disc',ctlpath,nx,ny,xll,yll,st_dt,yrlabel,nt=num_days)    
    # Print out a metadata textfile
    #meta(domain,name,out_path)
    print('disc gdat created for '+domain+' domain')
    
    # remove tc gdat
    tcfile = out_path+'/tc_'+yrlabel+'.gdat'
    # !rm -f $tcfile
# Out:
# 2018
# Working on timecoefs
# /scratch/Nina/NPRB/domain_BEAU/snowmodel2023_cfsv2/timecoef_fut
# tc gdat created for BEAU domain
# Working on HydroFlow
# /scratch/Nina/NPRB/domain_BEAU/snowmodel2023_cfsv2/hydroflow_fut
#  WORKING ON WATERSHED NUMBER         870
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         871
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         872
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         873
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         874
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         875
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         876
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         877
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         878
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         879
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         880
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         881
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         882
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         883
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         884
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         885
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         886
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         887
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         888
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         889
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         890
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         891
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         892
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         893
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         894
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         895
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         896
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         897
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         898
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         899
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         900
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         901
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         902
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         903
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         904
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         905
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         906
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         907
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         908
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         909
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         910
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         911
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         912
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         913
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         914
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         915
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         916
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         917
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         918
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         919
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         920
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         921
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         922
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         923
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         924
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         925
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         926
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         927
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         928
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         929
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         930
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         931
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         932
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         933
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         934
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         935
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         936
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         937
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         938
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         939
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         940
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         941
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         942
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         943
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         944
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         945
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         946
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         947
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         948
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         949
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         950
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         951
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         952
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         953
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         954
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         955
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         956
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         957
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         958
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         959
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         960
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         961
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         962
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         963
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         964
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         965
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         966
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         967
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         968
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         969
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         970
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         971
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         972
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         973
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         974
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         975
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         976
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         977
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         978
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         979
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         980
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         981
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         982
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         983
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         984
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         985
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         986
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         987
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         988
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         989
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         990
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         991
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         992
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         993
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         994
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         995
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         996
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         997
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         998
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER         999
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1000
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1001
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1002
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1003
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1004
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1005
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1006
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1007
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1008
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1009
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1010
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1011
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1012
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1013
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1014
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1015
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1016
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1017
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1018
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1019
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1020
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1021
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1022
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1023
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1024
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1025
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1026
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1027
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1028
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1029
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1030
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1031
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1032
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1033
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1034
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1035
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1036
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1037
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1038
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1039
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1040
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1041
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1042
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1043
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1044
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1045
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1046
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1047
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1048
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1049
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1050
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1051
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1052
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1053
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1054
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1055
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1056
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1057
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1058
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1059
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1060
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1061
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1062
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1063
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1064
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1065
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1066
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1067
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1068
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1069
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1070
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1071
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1072
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1073
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1074
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1075
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1076
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1077
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1078
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1079
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1080
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1081
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1082
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1083
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1084
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1085
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1086
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1087
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1088
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1089
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1090
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1091
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1092
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1093
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1094
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1095
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1096
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1097
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1098
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1099
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1100
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1101
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1102
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1103
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1104
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1105
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1106
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1107
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1108
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1109
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1110
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1111
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1112
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1113
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1114
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1115
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1116
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1117
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1118
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1119
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1120
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1121
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1122
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1123
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1124
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1125
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1126
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1127
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1128
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1129
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1130
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1131
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1132
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1133
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1134
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1135
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1136
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1137
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1138
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1139
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1140
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1141
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1142
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1143
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1144
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1145
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1146
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1147
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1148
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1149
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1150
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1151
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1152
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1153
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1154
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1155
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1156
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1157
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1158
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1159
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1160
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1161
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1162
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1163
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1164
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1165
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1166
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1167
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1168
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1169
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1170
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1171
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1172
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1173
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1174
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1175
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1176
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1177
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1178
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1179
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1180
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1181
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1182
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1183
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1184
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1185
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1186
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1187
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1188
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1189
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1190
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1191
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1192
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1193
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1194
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1195
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1196
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1197
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1198
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1199
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1200
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1201
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1202
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1203
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1204
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1205
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1206
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1207
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1208
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1209
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1210
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1211
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1212
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1213
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1214
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1215
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1216
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1217
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1218
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1219
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1220
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1221
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1222
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1223
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1224
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1225
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1226
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1227
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1228
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1229
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1230
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1231
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1232
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1233
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1234
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1235
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1236
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1237
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1238
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1239
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1240
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1241
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1242
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1243
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1244
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1245
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1246
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1247
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1248
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1249
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1250
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1251
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1252
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1253
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1254
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1255
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1256
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1257
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1258
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1259
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1260
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1261
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1262
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1263
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1264
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1265
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1266
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1267
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1268
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1269
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1270
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1271
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1272
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1273
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1274
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1275
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1276
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1277
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1278
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1279
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1280
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1281
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1282
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1283
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1284
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1285
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1286
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1287
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1288
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1289
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1290
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1291
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1292
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1293
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1294
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1295
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1296
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1297
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1298
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1299
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1300
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1301
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1302
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1303
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1304
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1305
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1306
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1307
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        1308
# ...
#  WORKING ON WATERSHED NUMBER        3088
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3089
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3090
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3091
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3092
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3093
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3094
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3095
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3096
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3097
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3098
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3099
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3100
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3101
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3102
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3103
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3104
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3105
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3106
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3107
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3108
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3109
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3110
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3111
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3112
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3113
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3114
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3115
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3116
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3117
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3118
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3119
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3120
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3121
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3122
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3123
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3124
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3125
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3126
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3127
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3128
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3129
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3130
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3131
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3132
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3133
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3134
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3135
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3136
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3137
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3138
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3139
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3140
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3141
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3142
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3143
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3144
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3145
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3146
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3147
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3148
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3149
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3150
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3151
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3152
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3153
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3154
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3155
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3156
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3157
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3158
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3159
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3160
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3161
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3162
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3163
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3164
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3165
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3166
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3167
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3168
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3169
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3170
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3171
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3172
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3173
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3174
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3175
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3176
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3177
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3178
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3179
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3180
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3181
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3182
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3183
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3184
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3185
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3186
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3187
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3188
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3189
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3190
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3191
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3192
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3193
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3194
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3195
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3196
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3197
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3198
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3199
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3200
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3201
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3202
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3203
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3204
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3205
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3206
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3207
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3208
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3209
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3210
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3211
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3212
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3213
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3214
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3215
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3216
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3217
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3218
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3219
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3220
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3221
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3222
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3223
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3224
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3225
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3226
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3227
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3228
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3229
#    solving the slow flow equation
#    solving the fast flow equation
#  WORKING ON WATERSHED NUMBER        3230
#    solving the slow flow equation
#    solving the fast flow equation
#
#  The following resident time coefficient values
#  (units=day) should range from about 0.2 to 100.
#
#        tc_min_s =    1.15740740
#        tc_max_s =    32.0000000
#        tc_ave_s =    1.14076483
#
#        tc_min_f =   0.114444003
#        tc_max_f =    3.20000005
#        tc_ave_f =   0.142595604
#
#  Time taken for code:    6602.45361     seconds.
# disc gdat created for BEAU domain
