# %%
import os
import numpy as np
import pandas as pd
import xarray as xr
import rioxarray as rxr
from datetime import datetime, date
import json
from xgrads import open_CtlDataset
import geopandas as gpd
import requests
import hydrofunctions as hf
import matplotlib.pyplot as plt
from shapely import geometry as sgeom
import folium 
# %matplotlib inline

# %%
# Choose a domain
domain = 'BEAU'

# Path to the SnowModel folder
gagepath = '/nfs/attic/dfh/2020_NPRB/data/stream_gage/'+domain+'/'

#path to NPRB domains
domains_resp = requests.get("https://raw.githubusercontent.com/NPRB/02_preprocess_python/main/NPRB_domains.json")
domains = domains_resp.json()

# SE AK
# domain_list = ['JUNE','KLAW','SITK','TAKU']
# arctic
# domain_list = ['BEAU', 'BRIS','CHUK','YUKO']
domain_list = ['BEAU']
# all domains have the same start date
st_dt = '1990-01-01'#'1990-10-01'#domains[domain]['st']
ed_dt = '2020-12-31'#'2020-09-30'#domains[domain]['ed']

# %%
# get database of USGS stations in the state of alaska
alaska = hf.NWIS(None,'dv', st_dt,ed_dt,parameterCd='00060',stateCd='AK', file='Q.parquet')
# build discharge dataframe
# gives discharge timeseries for each gague
akQ = alaska.df('discharge')
# list of station IDs
fullstnlist = [val[5:13] for val in akQ.columns]

# get lat lon for each station and build dataframe of metadata
for i in range(len(fullstnlist)):
    stn = fullstnlist[i]
    if i ==0:
        # individual station metadata in a df
        dfs = hf.site_file(stn).table
    else:
        try:
            output = hf.site_file(stn).table
            # add individual station to large df
            dfs = pd.concat([dfs, output])
        except:
            continue
# turn dataframe into geodataframe containing station metadata
gdfs = gpd.GeoDataFrame(dfs,geometry=gpd.points_from_xy(dfs.dec_long_va, dfs.dec_lat_va),crs='epsg:4326')
# Out:
# Reading data from Q.parquet
# Retrieved the site file for site #15008000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15008000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15009000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15009000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15015595 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15015595&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15019990 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15019990&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15022000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15022000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15024800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15024800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15028300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15028300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15039900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15039900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15040000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15040000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15041200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15041200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15049900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15049900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15050000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15050000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15051008 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15051008&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15051010 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15051010&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15052000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15052000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15052475 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15052475&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15052495 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15052495&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15052500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15052500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15052800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15052800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15053200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15053200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15055500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15055500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056030 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056030&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056095 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056095&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056210 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056210&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056280 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056280&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15056560 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15056560&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15057580 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15057580&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15057596 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15057596&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15058700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15058700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15067900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15067900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15068040 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15068040&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15072000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15072000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081495 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081495&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081497 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081497&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081580 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081580&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081610 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081610&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081614 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081614&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15081995 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15081995&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15083500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15083500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15085100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15085100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15085800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15085800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15085900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15085900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15086225 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15086225&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15086960 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15086960&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087565 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087565&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087570 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087570&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087618 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087618&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087690 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087690&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087730 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087730&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087735 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087735&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15087810 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15087810&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15088000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15088000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15088200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15088200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15099900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15099900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15100000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15100000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15101490 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15101490&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15101500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15101500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15102200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15102200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15106920 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15106920&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15106970 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15106970&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15108800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15108800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15109048 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15109048&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129120 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129120&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129280 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129280&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129510 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129510&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15129600 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15129600&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15199500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15199500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15200280 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15200280&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15209700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15209700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15209750 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15209750&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15209800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15209800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15212000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15212000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15214000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15214000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15215900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15215900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15215990 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15215990&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15215992 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15215992&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15216000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15216000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15216003 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15216003&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15216008 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15216008&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15219000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15219000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15225996 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15225996&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15225997 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15225997&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15225998 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15225998&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15226000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15226000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15226620 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15226620&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15227090 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15227090&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15236000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15236000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15236210 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15236210&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15236900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15236900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15237030 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15237030&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15237360 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15237360&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15237730 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15237730&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238450 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238450&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238450 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238450&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238450 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238450&siteOutput=expanded&siteStatus=alll
# The USGS has returned an error code of 4040 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238490&siteOutput=expanded&siteStatus=all
# Retrieved the site file for site #15238500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238600 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238600&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238648 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238648&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238820 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238820&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238978 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238978&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238982 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238982&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238984 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238984&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238985 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238985&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238986 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238986&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15238990 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15238990&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239001 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239001&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239050 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239050&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239060 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239060&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239070 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239070&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15239900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15239900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15241600 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15241600&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15243900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15243900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15258000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15258000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15261000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15261000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15266110 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15266110&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15266150 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15266150&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15266300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15266300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15271000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15271000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15272280 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15272280&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15272380 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15272380&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15272502 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15272502&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15273045 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15273045&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15274000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15274000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15274550 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15274550&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15274600 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15274600&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15275100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15275100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15276000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15276000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15276200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15276200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15276320 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15276320&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15277600 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15277600&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15277800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15277800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15280200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15280200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15280900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15280900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15280999 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15280999&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15281000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15281000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15281500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15281500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15283700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15283700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15284000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15284000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15285000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15285000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15286000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15286000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15290000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15290000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15291000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15291000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15291700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15291700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15292000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15292000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15292400 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15292400&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15292700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15292700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15292780 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15292780&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15292800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15292800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15293200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15293200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15293700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15293700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294005 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294005&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294080 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294080&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294345 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294345&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294350 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294350&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294585 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294585&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294640 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294640&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15294900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15294900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15295700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15295700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297475 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297475&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297485 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297485&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297580 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297580&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297585 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297585&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297610 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297610&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297617 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297617&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15297625 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15297625&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15298040 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15298040&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15300100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15300100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15300200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15300200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15300250 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15300250&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15300300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15300300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15300520 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15300520&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15301500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15301500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302200 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302200&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302250 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302250&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302320 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302320&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15302812 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15302812&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15303010 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15303010&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15303011 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15303011&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15303700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15303700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15303900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15303900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15304000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15304000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15304010 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15304010&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15304293 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15304293&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15304400 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15304400&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15310002 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15310002&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15320100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15320100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15330000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15330000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15331000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15331000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15348000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15348000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15356000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15356000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15388030 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15388030&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15388060 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15388060&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15388070 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15388070&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15389100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15389100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15392000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15392000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15446000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15446000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15452100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15452100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15452300 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15452300&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15453500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15453500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15457790 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15457790&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15457800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15457800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15476000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15476000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477730 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477730&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477740 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477740&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477761 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477761&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477768 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477768&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477770 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477770&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15477790 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15477790&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15478040 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15478040&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15484000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15484000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15485500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15485500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15493000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15493000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15493400 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15493400&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15493700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15493700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15511000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15511000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15514000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15514000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15515048 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15515048&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15515060 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15515060&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15515080 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15515080&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15515500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15515500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15518020 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15518020&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15518040 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15518040&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15518080 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15518080&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15518900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15518900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15519030 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15519030&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15519100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15519100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15519150 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15519150&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15534800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15534800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15564450 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15564450&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15564879 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15564879&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15565400 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15565400&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15565447 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15565447&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15565700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15565700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15580095 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15580095&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15583500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15583500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15621000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15621000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15625850 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15625850&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15625900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15625900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15635000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15635000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15716010 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15716010&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15743850 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15743850&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15744500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15744500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746900 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746900&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746980 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746980&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746983 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746983&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746988 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746988&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746990 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746990&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746990 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746990&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15746991 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15746991&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15747000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15747000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15798700 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15798700&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15803000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15803000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15820000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15820000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15860000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15860000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15861000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15861000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15862500 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15862500&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15875000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15875000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15896000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15896000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15904800 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15904800&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15905100 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15905100&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15906000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15906000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15908000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15908000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15955000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15955000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15960000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15960000&siteOutput=expanded&siteStatus=alll
# Retrieved the site file for site #15980000 from https://waterservices.usgs.gov/nwis/site/?format=rdb&sites=15980000&siteOutput=expanded&siteStatus=alll

# %%
# select stations in the domain
SHAPEpath = '/nfs/attic/dfh/2020_NPRB/data/gis/'+domain+'/'+domain+'.json'
# open shapefile of interest basin
domgdf = gpd.read_file(SHAPEpath)
#index of stations that fall into in the domain
mask = gdfs.within(domgdf.loc[0].geometry)
#gdf of stns in the domain
gdfclip = gdfs.loc[mask]
stnlist = gdfclip.site_no.tolist()
stnlist
# Out:
# ['15798700',
#  '15803000',
#  '15820000',
#  '15860000',
#  '15861000',
#  '15862500',
#  '15875000',
#  '15896000',
#  '15904800',
#  '15905100',
#  '15906000',
#  '15908000',
#  '15955000',
#  '15960000',
#  '15980000']

# %%
# just select column with information of interest
infoclip = gdfclip[['site_no','drain_area_va','contrib_drain_area_va']]
infoclip
# Out:
#     site_no  drain_area_va  contrib_drain_area_va
# 0  15798700            2.9                    NaN
# 0  15803000         1790.0                    NaN
# 0  15820000         1700.0                    NaN
# 0  15860000          791.0                    NaN
# 0  15861000          655.0                    NaN
# 0  15862500          190.0                    NaN
# 0  15875000        13860.0                    NaN
# 0  15896000         3340.0                    NaN
# 0  15904800           40.9                    NaN
# 0  15905100          297.0                    NaN
# 0  15906000           28.3                    NaN
# 0  15908000         1850.0                    NaN
# 0  15955000         1930.0                    NaN
# 0  15960000          149.0                    NaN
# 0  15980000          687.0                    NaN

# %%
# # station with largest upslope area
# akQ['USGS:15744500:00060:00003'].plot()

# %%
# create df to determine which years have data at each gage
# list of water years
years = np.arange(1990,2021)
# empty array
datayrs = np.empty([len(years),len(stnlist)])

for s in range(len(stnlist)):
    #select station
    stn = stnlist[s]
    # dataframe of Q across domain
    akQs = akQ[akQ.columns.intersection(['USGS:'+stn+':00060:00003'])]
    yrlst = []
    for y in range(len(years)):
        # select year
        yr = years[y]
        #start date
        st = str(yr-1)+'-10-01'
        #end date
        ed = str(yr)+'-09-30'
        # slice discharge values to time period of interest
        Qdf = akQs[st:ed]
        # if there are less than 5 days missing - include year
        if len(Qdf[np.isnan(Qdf['USGS:'+stn+':00060:00003'])])<5:
            datayrs[y,s]=1
            yrlst.append(yr)
        else:
            datayrs[y,s]=0
    print(stn)
    print(yrlst)
        
# turn into dataframe
df = pd.DataFrame(data=datayrs, index=years,columns=[stnlist])
# Out:
# 15798700
# [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004]
# 15803000
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 15820000
# [2005, 2006, 2007, 2008, 2009]
# 15860000
# [2005, 2006, 2007, 2008, 2009]
# 15861000
# [2005, 2006, 2007, 2008, 2009]
# 15862500
# [2007, 2008, 2009]
# 15875000
# [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 15896000
# [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 15904800
# [1992, 1993, 1994, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]
# 15905100
# [2011, 2012, 2013, 2014, 2015, 2016, 2017]
# 15906000
# [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007]
# 15908000
# [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 15955000
# [2009, 2010, 2011, 2012]
# 15960000
# [2009, 2010, 2011, 2012]
# 15980000
# [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
# number of stations with Q data each year 
df.sum(axis=1)
# Out:
# 1990     4.0
# 1991     4.0
# 1992     5.0
# 1993     5.0
# 1994     5.0
# 1995     4.0
# 1996     4.0
# 1997     4.0
# 1998     4.0
# 1999     4.0
# 2000     4.0
# 2001     5.0
# 2002     6.0
# 2003     6.0
# 2004     6.0
# 2005     9.0
# 2006     9.0
# 2007    10.0
# 2008    11.0
# 2009    11.0
# 2010     6.0
# 2011     8.0
# 2012     8.0
# 2013     6.0
# 2014     6.0
# 2015     6.0
# 2016     6.0
# 2017     6.0
# 2018     6.0
# 2019     6.0
# 2020     6.0
# dtype: float64

# %%
# number of years of data at each station 
df.sum(axis=0)
# Out:
# 15798700    15.0
# 15803000    16.0
# 15820000     5.0
# 15860000     5.0
# 15861000     5.0
# 15862500     3.0
# 15875000    19.0
# 15896000    31.0
# 15904800    12.0
# 15905100    10.0
# 15906000    18.0
# 15908000    31.0
# 15955000     5.0
# 15960000     5.0
# 15980000    10.0
# dtype: float64

# %%
# add information on number of years with data 
infoclip['data_years'] = df.sum(axis=0).values
# Out:
# /tmp/ipykernel_125218/3070973863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   infoclip['data_years'] = df.sum(axis=0).values

# %%
infoclip
# Out:
#     site_no  drain_area_va  contrib_drain_area_va  data_years
# 0  15798700            2.9                    NaN        15.0
# 0  15803000         1790.0                    NaN        16.0
# 0  15820000         1700.0                    NaN         5.0
# 0  15860000          791.0                    NaN         5.0
# 0  15861000          655.0                    NaN         5.0
# 0  15862500          190.0                    NaN         3.0
# 0  15875000        13860.0                    NaN        19.0
# 0  15896000         3340.0                    NaN        31.0
# 0  15904800           40.9                    NaN        12.0
# 0  15905100          297.0                    NaN        10.0
# 0  15906000           28.3                    NaN        18.0
# 0  15908000         1850.0                    NaN        31.0
# 0  15955000         1930.0                    NaN         5.0
# 0  15960000          149.0                    NaN         5.0
# 0  15980000          687.0                    NaN        10.0

# %%
# large watersheds with data in calibration years
lgsd = ['15803000','15875000','15896000','15908000']

# %% [markdown]
# ## plot

# %%
#watershed data
ctlFile = '/nfs/attic/dfh/2020_NPRB/domain_'+domain+'/snowmodel2023_cfsv2/watershed/watershed_'+domain+'.ctl'

wd = open_CtlDataset(ctlFile)
wd
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, lev: 1, lat: 798, lon: 763)
# Coordinates:
#   * time     (time) datetime64[ns] 2001-09-01
#   * lev      (lev) float64 1.0
#   * lat      (lat) float32 1.361e+06 1.362e+06 1.363e+06 ... 2.157e+06 2.158e+06
#   * lon      (lon) float32 -7.44e+05 -7.43e+05 -7.42e+05 ... 1.7e+04 1.8e+04
# Data variables:
#     dir      (time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 798, 763), meta=np.ndarray>
#     wshed    (time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 798, 763), meta=np.ndarray>
#     order    (time, lev, lat, lon) float32 dask.array<chunksize=(1, 1, 798, 763), meta=np.ndarray>
# Attributes:
#     comment:  flow direction
#     storage:  0
#     title:    xxxxxxxxxxxxxxxxxxxxxxxxx
#     undef:    -9999.0
#     pdef:     None

# %%
# huc2 vector file
shp = gpd.read_file('/nfs/attic/dfh/2020_NPRB/data/gis/'+domain+'/'+domain+'.json')
# projected coordinates
shpproj = shp.to_crs(domains[domain]['mod_proj'])
# add column to create a binary mask in rasterized version
shpproj['mask'] = 1
# load upslope watershed area masks
upslope = xr.open_dataset(gagepath+'upslope.nc')
upslope
# Out:
# <xarray.Dataset>
# Dimensions:      (y: 798, x: 763)
# Coordinates:
#     band         int64 ...
#   * y            (y) float64 2.158e+06 2.158e+06 ... 1.362e+06 1.362e+06
#   * x            (x) float64 -7.435e+05 -7.425e+05 ... 1.75e+04 1.85e+04
#     spatial_ref  int64 ...
# Data variables:
#     15565700     (y, x) float32 ...
#     15580095     (y, x) float32 ...
#     15621000     (y, x) float32 ...
#     15744500     (y, x) float32 ...
#     15746900     (y, x) float32 ...
#     15746980     (y, x) float32 ...
#     15746990     (y, x) float32 ...
#     15746991     (y, x) float32 ...
#     15747000     (y, x) float32 ...

# %%
# plot
fig,ax = plt.subplots(figsize=[6,4])
shpproj.plot(ax=ax,facecolor='None',edgecolor='r')
wd.wshed.where(wd.wshed==3375).plot(ax=ax)
upslope['15744500'].plot(ax=ax,cmap='plasma')

# %%
wsd = wd.wshed.squeeze()
wsd
# Out:
# <xarray.DataArray 'wshed' (lat: 798, lon: 763)>
# dask.array<getitem, shape=(798, 763), dtype=float32, chunksize=(798, 763), chunktype=numpy.ndarray>
# Coordinates:
#     time     datetime64[ns] 2001-09-01
#     lev      float64 1.0
#   * lat      (lat) float32 1.361e+06 1.362e+06 1.363e+06 ... 2.157e+06 2.158e+06
#   * lon      (lon) float32 -7.44e+05 -7.43e+05 -7.42e+05 ... 1.7e+04 1.8e+04
# Attributes:
#     comment:  watersheds
#     storage:  0

# %%
uq = np.unique(wsd.values)
count = []
for val in uq:
    count.append(len(wsd.values[wsd.values==val]))

# %%
wddf = pd.DataFrame({'wdid':uq,'count':count})
wddf.sort_values(by=['count'],ascending=False)
# Out:
#         wdid   count
# 0        0.0  210241
# 82      82.0   98187
# 3493  3493.0   32199
# 3375  3375.0   29636
# 555    555.0   25867
# ...      ...     ...
# 2016  2016.0       2
# 2015  2015.0       2
# 2014  2014.0       2
# 2013  2013.0       2
# 1972  1972.0       2
#
# [3945 rows x 2 columns]
